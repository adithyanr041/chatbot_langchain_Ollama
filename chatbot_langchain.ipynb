# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate

template = """
Answer the question below.

here is the converstaion history:{context}

Question : {question}

Answer:

"""

model = OllamaLLM(model="llama3")
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | model




def conversation_handling():
    context = ""
    print("Welcome to the AI cahtbot! Type 'exit' to exit")
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break
        result = chain.invoke({"context":context , "question":user_input})
        print("Bot: ", result)
        context += f"\nUser:{user_input}\nAI: {result}"

if __name__ == "__main__":
    conversation_handling()
# Out:
# Welcome to the AI cahtbot! Type 'exit' to exit
# You:  how are you
# Bot:  I'm doing well, thanks for asking!
# You:  what are you?
# Bot:  I'm an artificial intelligence language model!
# You:  exit
